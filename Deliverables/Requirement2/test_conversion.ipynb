# %%
from conversion_probability import conversion_probability 
import numpy as np
import matplotlib.pyplot as plt

conversion = conversion_probability(0.5,1000)

conversion_prob = conversion.conversion_probability()

prices = np.linspace(0,10,100)

plt.plot(prices,[conversion_prob(price) for price in prices])
